# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Untitled-1.ipynb Cell 1 line 5
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=2'>3</a> import seaborn as sns
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=3'>4</a> import matplotlib.pyplot as plt
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=4'>5</a> import missingno as msno
#
# ModuleNotFoundError: No module named 'missingno'

# %%
df = pd.read_csv('Dados_PRF_2022_translated.csv.xls', delimiter=';')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64547 entries, 0 to 64546
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       64547 non-null  int64
#  1   date                     64547 non-null  object
#  2   weekday                  64547 non-null  object
#  3   time                     64547 non-null  object
#  4   state                    64547 non-null  object
#  5   highway                  64350 non-null  float64
#  6   kilometer                64350 non-null  object
#  7   city                     64547 non-null  object
#  8   accident_cause           64547 non-null  object
#  9   accident_type            64547 non-null  object
#  10  accident_classification  64547 non-null  object
#  11  time_of_day              64547 non-null  object
#  12  direction                64547 non-null  object
#  13  weather_condition        64547 non-null  object
#  14  type_of_road             64547 non-null  object
#  15  road_layout              64547 non-null  object
#  16  urban_rural              64547 non-null  object
#  17  people                   64547 non-null  int64
#  18  deceased                 64547 non-null  int64
#  19  lightly_injured          64547 non-null  int64
#  20  severely_injured         64547 non-null  int64
#  21  unharmed                 64547 non-null  int64
#  22  unknown                  64547 non-null  int64
#  23  injured                  64547 non-null  int64
#  24  vehicles                 64547 non-null  int64
#  25  latitude                 64547 non-null  object
#  26  longitude                64547 non-null  object
#  27  regional                 64544 non-null  object
#  28  police_station           63788 non-null  object
#  29  operational_unit         64499 non-null  object
# dtypes: float64(1), int64(9), object(20)
# memory usage: 14.8+ MB

# %%
df.describe()
# Out:
#                   ID       highway        people      deceased  \
# count   64547.000000  64350.000000  64547.000000  64547.000000
# mean   456895.545417    212.692510      2.405472      0.084264
# std     27163.593029    130.784085      2.069921      0.334792
# min    405147.000000     10.000000      1.000000      0.000000
# 25%    443047.500000    101.000000      1.000000      0.000000
# 50%    461064.000000    163.000000      2.000000      0.000000
# 75%    479342.500000    324.000000      3.000000      0.000000
# max    517156.000000    495.000000     75.000000      7.000000
#
#        lightly_injured  severely_injured      unharmed       unknown  \
# count     64547.000000      64547.000000  64547.000000  64547.000000
# mean          0.849598          0.280912      1.026198      0.164500
# std           1.073940          0.615196      1.636206      0.505713
# min           0.000000          0.000000      0.000000      0.000000
# 25%           0.000000          0.000000      0.000000      0.000000
# 50%           1.000000          0.000000      1.000000      0.000000
# 75%           1.000000          0.000000      1.000000      0.000000
# max          50.000000         31.000000     56.000000     54.000000
#
#             injured      vehicles
# count  64547.000000  64547.000000
# mean       1.130510      1.652982
# std        1.202904      0.723022
# min        0.000000      1.000000
# 25%        1.000000      1.000000
# 50%        1.000000      2.000000
# 75%        1.000000      2.000000
# max       55.000000     21.000000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# ID                           0
# date                         0
# weekday                      0
# time                         0
# state                        0
# highway                    197
# kilometer                  197
# city                         0
# accident_cause               0
# accident_type                0
# accident_classification      0
# time_of_day                  0
# direction                    0
# weather_condition            0
# type_of_road                 0
# road_layout                  0
# urban_rural                  0
# people                       0
# deceased                     0
# lightly_injured              0
# severely_injured             0
# unharmed                     0
# unknown                      0
# injured                      0
# vehicles                     0
# latitude                     0
# longitude                    0
# regional                     3
# police_station             759
# operational_unit            48
# dtype: int64

# %%
# Create a DataFrame with missing value information
missing_data = df.isnull()

# Calculate the total number of missing values in each column
missing_count = missing_data.sum()

# Create a bar plot to visualize missing values
plt.figure(figsize=(10, 6))
plt.bar(missing_count.index, missing_count.values)
plt.xlabel('Columns')
plt.ylabel('Number of Missing Values')
plt.title('Missing Value Plot')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()

# %%
#Replace null values

df.replace(np.nan,'0',inplace = True)

#Check the changes now
df.isnull().sum()
# Out:
# ID                         0
# date                       0
# weekday                    0
# time                       0
# state                      0
# highway                    0
# kilometer                  0
# city                       0
# accident_cause             0
# accident_type              0
# accident_classification    0
# time_of_day                0
# direction                  0
# weather_condition          0
# type_of_road               0
# road_layout                0
# urban_rural                0
# people                     0
# deceased                   0
# lightly_injured            0
# severely_injured           0
# unharmed                   0
# unknown                    0
# injured                    0
# vehicles                   0
# latitude                   0
# longitude                  0
# regional                   0
# police_station             0
# operational_unit           0
# dtype: int64

# %%
#Datatypes

df.dtypes
# Out:
# ID                          int64
# date                       object
# weekday                    object
# time                       object
# state                      object
# highway                    object
# kilometer                  object
# city                       object
# accident_cause             object
# accident_type              object
# accident_classification    object
# time_of_day                object
# direction                  object
# weather_condition          object
# type_of_road               object
# road_layout                object
# urban_rural                object
# people                      int64
# deceased                    int64
# lightly_injured             int64
# severely_injured            int64
# unharmed                    int64
# unknown                     int64
# injured                     int64
# vehicles                    int64
# latitude                   object
# longitude                  object
# regional                   object
# police_station             object
# operational_unit           object
# dtype: object

# %%
df.corr()
# Out:
# C:\Users\kjeld\AppData\Local\Temp\ipykernel_18760\1886530979.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                         ID    people  deceased  lightly_injured  \
# ID                1.000000  0.015610  0.009041         0.003381
# people            0.015610  1.000000  0.177032         0.478488
# deceased          0.009041  0.177032  1.000000        -0.060798
# lightly_injured   0.003381  0.478488 -0.060798         1.000000
# severely_injured  0.013438  0.250677  0.072297        -0.064203
# unharmed          0.008128  0.764122  0.003550         0.003001
# unknown           0.008081  0.182529  0.092264        -0.056483
# injured           0.009891  0.555392 -0.017305         0.859954
# vehicles          0.016077  0.414342  0.050783         0.089430
#
#                   severely_injured  unharmed   unknown   injured  vehicles
# ID                        0.013438  0.008128  0.008081  0.009891  0.016077
# people                    0.250677  0.764122  0.182529  0.555392  0.414342
# deceased                  0.072297  0.003550  0.092264 -0.017305  0.050783
# lightly_injured          -0.064203  0.003001 -0.056483  0.859954  0.089430
# severely_injured          1.000000 -0.039018  0.024266  0.454106  0.069109
# unharmed                 -0.039018  1.000000 -0.069093 -0.017276  0.404286
# unknown                   0.024266 -0.069093  1.000000 -0.038017  0.080279
# injured                   0.454106 -0.017276 -0.038017  1.000000  0.115187
# vehicles                  0.069109  0.404286  0.080279  0.115187  1.000000
